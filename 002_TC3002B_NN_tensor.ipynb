# %% [markdown]
# ## **A simple computer vision model using Keras**

# %% [markdown]
# ## Input data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf

# %%
num_classes = 10
img_rows, img_cols = 28, 28
num_channels = 1
input_shape = (img_rows, img_cols, num_channels)

(x_train, y_train),(x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ## Building a simple model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

# %% [markdown]
# ## Launch training

# %%
model.compile(optimizer='sgd',                               # Optimizer: This is the component that will operate the gradient descent.
              loss='sparse_categorical_crossentropy',        # Loss: This is the metric we will optimize
              metrics=['accuracy'])                          # Metrics: These are additional metric functions evaluated during training to provide further visibility over the model's performance
callbacks = [tf.keras.callbacks.TensorBoard('./keras')]
model.fit(x_train, y_train, epochs=25, verbose=1, validation_data=(x_test, y_test), callbacks=callbacks) # running the trainning process

# %%
model.summary() # get a description of the model

# %% [markdown]
# ## Getting Predictions

# %%
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(x_test, y_test, batch_size=10)
print("test loss, test acc:", results)
