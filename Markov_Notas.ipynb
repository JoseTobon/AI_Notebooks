# %%
import numpy as np
import sounddevice as sd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 import sounddevice as sd
#
# ModuleNotFoundError: No module named 'sounddevice'

# %%
estados = ["do", "re", "mi", "fa", "sol", "la", "si"]

frecuencias = {
    "do": 261.63,
    "re": 293.66,
    "mi": 329.63,
    "fa": 349.23,
    "sol": 392.00,
    "la": 440.00,
    "si": 493.88
}

matriz_transicion = np.array([
    [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #do
    [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #re
    [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #mi
    [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #fa
    [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #sol
    [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #la
    [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7]  #si
])

cadena = [np.random.choice(states)]
print(cadena)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#       1 estados = ["do", "re", "mi", "fa", "sol", "la", "si"]
#       3 frecuencias = {
#       4     "do": 261.63,
#       5     "re": 293.66,
#    (...)
#      10     "si": 493.88
#      11 }
# ---> 13 matriz_transicion = np.array([
#      14     [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #do
#      15     [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #re
#      16     [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #mi
#      17     [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #fa
#      18     [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #sol
#      19     [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7], #la
#      20     [1/7, 1/7, 1/7, 1/7, 1/7, 1/7, 1/7]  #si
#      21 ])
#      23 cadena = [np.random.choice(states)]
#      24 print(cadena)
#
# NameError: name 'np' is not defined
